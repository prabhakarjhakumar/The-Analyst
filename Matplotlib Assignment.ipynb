# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a library in python. It is used to plot different types of plot as per our requiements. Following plots can be plotted with help of this:
# 1. line plot
# 2. Scatter plot
# 3. Barplot
# 4. Barplot horizontal
# 5. Histogram

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import numpy as np
import matplotlib as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %% [markdown]
# A scatter plot is a visual representation of how two variables relate to each other. We can use scatter plots to explore the relationship between two variables, for example by looking for any correlation between them.

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.xlabel("This is X-axis")
plt.ylabel("This is Y-axis")
plt.title("This is X vs Y Scatter Chart")
# Out:
# Text(0.5, 1.0, 'This is X vs Y Scatter Chart')

# %%
#Q.3.

import numpy as np
#For line 1: 
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
#For line 2: 
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([50, 20, 40, 20, 60, 70])
#For line 3: 
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([10, 20, 30, 40, 50, 60])
#For line 4: 
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([200, 350, 250, 550, 450, 150])

# %%
fig, (ax, ax1, ax2,ax3) = plt.subplots(4, sharex=True)
ax.plot(x,y)
ax1.plot(x1,y1)
ax2.plot(x2,y2)
ax3.plot(x3,y3)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# A bar chart is a graphical approach to categorical vs numerical data. Its helps us to understand the quantitative distribution of components plotted on X axis.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]

# %%
fig = plt.figure(figsize =(5, 3))
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
# Creating plot
bp = ax.boxplot(data)
